# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from collections import Counter

# %%
G1=nx.Graph()

G1.add_edge("NGO1","GP1",weight=1)
G1.add_edge("NGO2","GP1",weight=1)
G1.add_edge("NGO5","GP1",weight=1)
G1.add_edge("NGO20","GP1",weight=1)
G1.add_edge("NGO221","GP1",weight=1)
G1.add_edge("NGO245","GP1",weight=1)
G1.add_edge("NGO1","GP2",weight=1)
G1.add_edge("NGO2","GP2",weight=1)
G1.add_edge("NGO20","GP2",weight=1)
G1.add_edge("NGO25","GP2",weight=1)
G1.add_edge("NGO81","GP2",weight=1)
G1.add_edge("NGO82","GP2",weight=1)
G1.add_edge("NGO221","GP2",weight=1)
G1.add_edge("NGO273","GP2",weight=1)
G1.add_edge("NGO276","GP2",weight=1)
G1.add_edge("NGO279","GP2",weight=1)
G1.add_edge("NGO1","GP3",weight=1)
G1.add_edge("NGO2","GP3",weight=1)
G1.add_edge("NGO2","GP4",weight=1)
G1.add_edge("NGO2","GP5",weight=1)
G1.add_edge("NGO1","GP6",weight=1)
G1.add_edge("NGO2","GP6",weight=1)
G1.add_edge("NGO10","GP6",weight=1)
G1.add_edge("NGO20","GP6",weight=1)
G1.add_edge("NGO21","GP6",weight=1)
G1.add_edge("NGO50","GP6",weight=1)
G1.add_edge("NGO81","GP6",weight=1)
G1.add_edge("NGO132","GP6",weight=1)
G1.add_edge("NGO136","GP6",weight=1)
G1.add_edge("NGO150","GP6",weight=1)
G1.add_edge("NGO197","GP6",weight=1)
G1.add_edge("NGO221","GP6",weight=1)
G1.add_edge("NGO242","GP6",weight=1)
G1.add_edge("NGO268","GP6",weight=1)
G1.add_edge("NGO272","GP6",weight=1)
G1.add_edge("NGO275","GP6",weight=1)
G1.add_edge("NGO2","GP7",weight=1)
G1.add_edge("NGO2","GP8",weight=1)
G1.add_edge("NGO179","GP8",weight=1)
G1.add_edge("NGO182","GP8",weight=1)
G1.add_edge("NGO2","GP9",weight=1)
G1.add_edge("NGO2","GP10",weight=1)
G1.add_edge("NGO1","GP11",weight=1)
G1.add_edge("NGO2","GP11",weight=1)
G1.add_edge("NGO7","GP11",weight=1)
G1.add_edge("NGO10","GP11",weight=1)
G1.add_edge("NGO13","GP11",weight=1)
G1.add_edge("NGO17","GP11",weight=1)
G1.add_edge("NGO19","GP11",weight=1)
G1.add_edge("NGO20","GP11",weight=1)
G1.add_edge("NGO21","GP11",weight=1)
G1.add_edge("NGO25","GP11",weight=1)
G1.add_edge("NGO50","GP11",weight=1)
G1.add_edge("NGO81","GP11",weight=1)
G1.add_edge("NGO99","GP11",weight=1)
G1.add_edge("NGO129","GP11",weight=1)
G1.add_edge("NGO150","GP11",weight=1)
G1.add_edge("NGO186","GP11",weight=1)
G1.add_edge("NGO220","GP11",weight=1)
G1.add_edge("NGO221","GP11",weight=1)
G1.add_edge("NGO222","GP11",weight=1)
G1.add_edge("NGO225","GP11",weight=1)
G1.add_edge("NGO244","GP11",weight=1)
G1.add_edge("NGO245","GP11",weight=1)
G1.add_edge("NGO266","GP11",weight=1)
G1.add_edge("NGO270","GP11",weight=1)
G1.add_edge("NGO272","GP11",weight=1)
G1.add_edge("NGO273","GP11",weight=1)
G1.add_edge("NGO274","GP11",weight=1)
G1.add_edge("NGO275","GP11",weight=1)
G1.add_edge("NGO276","GP11",weight=1)
G1.add_edge("NGO1","GP12",weight=1)
G1.add_edge("NGO11","GP12",weight=1)
G1.add_edge("NGO193","GP12",weight=1)
G1.add_edge("NGO199","GP12",weight=1)
G1.add_edge("NGO269","GP12",weight=1)
G1.add_edge("NGO1","GP13",weight=1)
G1.add_edge("NGO10","GP13",weight=1)
G1.add_edge("NGO55","GP13",weight=1)
G1.add_edge("NGO56","GP13",weight=1)
G1.add_edge("NGO92","GP13",weight=1)
G1.add_edge("NGO182","GP13",weight=1)
G1.add_edge("NGO194","GP13",weight=1)
G1.add_edge("NGO197","GP13",weight=1)
G1.add_edge("NGO221","GP13",weight=1)
G1.add_edge("NGO268","GP13",weight=1)
G1.add_edge("NGO278","GP13",weight=1)
G1.add_edge("NGO2","GP14",weight=1)
G1.add_edge("NGO94","GP14",weight=1)
G1.add_edge("NGO2","GP15",weight=1)
G1.add_edge("NGO4","GP15",weight=1)
G1.add_edge("NGO6","GP15",weight=1)
G1.add_edge("NGO7","GP15",weight=1)
G1.add_edge("NGO10","GP15",weight=1)
G1.add_edge("NGO11","GP15",weight=1)
G1.add_edge("NGO17","GP15",weight=1)
G1.add_edge("NGO28","GP15",weight=1)
G1.add_edge("NGO46","GP15",weight=1)
G1.add_edge("NGO49","GP15",weight=1)
G1.add_edge("NGO51","GP15",weight=1)
G1.add_edge("NGO52","GP15",weight=1)
G1.add_edge("NGO54","GP15",weight=1)
G1.add_edge("NGO56","GP15",weight=1)
G1.add_edge("NGO81","GP15",weight=1)
G1.add_edge("NGO98","GP15",weight=1)
G1.add_edge("NGO132","GP15",weight=1)
G1.add_edge("NGO136","GP15",weight=1)
G1.add_edge("NGO139","GP15",weight=1)
G1.add_edge("NGO142","GP15",weight=1)
G1.add_edge("NGO144","GP15",weight=1)
G1.add_edge("NGO176","GP15",weight=1)
G1.add_edge("NGO182","GP15",weight=1)
G1.add_edge("NGO186","GP15",weight=1)
G1.add_edge("NGO187","GP15",weight=1)
G1.add_edge("NGO189","GP15",weight=1)
G1.add_edge("NGO192","GP15",weight=1)
G1.add_edge("NGO195","GP15",weight=1)
G1.add_edge("NGO197","GP15",weight=1)
G1.add_edge("NGO198","GP15",weight=1)
G1.add_edge("NGO242","GP15",weight=1)
G1.add_edge("NGO244","GP15",weight=1)
G1.add_edge("NGO246","GP15",weight=1)
G1.add_edge("NGO266","GP15",weight=1)
G1.add_edge("NGO268","GP15",weight=1)
G1.add_edge("NGO273","GP15",weight=1)
G1.add_edge("NGO4","GP16",weight=1)
G1.add_edge("NGO4","GP17",weight=1)
G1.add_edge("NGO176","GP17",weight=1)
G1.add_edge("NGO4","GP18",weight=1)
G1.add_edge("NGO7","GP18",weight=1)
G1.add_edge("NGO48","GP18",weight=1)
G1.add_edge("NGO4","GP19",weight=1)
G1.add_edge("NGO7","GP19",weight=1)
G1.add_edge("NGO10","GP19",weight=1)
G1.add_edge("NGO25","GP19",weight=1)
G1.add_edge("NGO27","GP19",weight=1)
G1.add_edge("NGO50","GP19",weight=1)
G1.add_edge("NGO225","GP19",weight=1)
G1.add_edge("NGO242","GP19",weight=1)
G1.add_edge("NGO246","GP19",weight=1)
G1.add_edge("NGO248","GP19",weight=1)
G1.add_edge("NGO266","GP19",weight=1)
G1.add_edge("NGO269","GP19",weight=1)
G1.add_edge("NGO270","GP19",weight=1)
G1.add_edge("NGO4","GP20",weight=1)
G1.add_edge("NGO216","GP20",weight=1)
G1.add_edge("NGO4","GP21",weight=1)
G1.add_edge("NGO7","GP21",weight=1)
G1.add_edge("NGO10","GP21",weight=1)
G1.add_edge("NGO20","GP21",weight=1)
G1.add_edge("NGO25","GP21",weight=1)
G1.add_edge("NGO27","GP21",weight=1)
G1.add_edge("NGO50","GP21",weight=1)
G1.add_edge("NGO140","GP21",weight=1)
G1.add_edge("NGO221","GP21",weight=1)
G1.add_edge("NGO225","GP21",weight=1)
G1.add_edge("NGO242","GP21",weight=1)
G1.add_edge("NGO244","GP21",weight=1)
G1.add_edge("NGO246","GP21",weight=1)
G1.add_edge("NGO248","GP21",weight=1)
G1.add_edge("NGO266","GP21",weight=1)
G1.add_edge("NGO269","GP21",weight=1)
G1.add_edge("NGO274","GP21",weight=1)
G1.add_edge("NGO279","GP21",weight=1)
G1.add_edge("NGO4","GP22",weight=1)
G1.add_edge("NGO4","GP23",weight=1)
G1.add_edge("NGO10","GP23",weight=1)
G1.add_edge("NGO196","GP23",weight=1)
G1.add_edge("NGO5","GP24",weight=1)
G1.add_edge("NGO7","GP25",weight=1)
G1.add_edge("NGO94","GP25",weight=1)
G1.add_edge("NGO134","GP25",weight=1)
G1.add_edge("NGO173","GP25",weight=1)
G1.add_edge("NGO273","GP25",weight=1)
G1.add_edge("NGO13","GP26",weight=1)
G1.add_edge("NGO17","GP26",weight=1)
G1.add_edge("NGO25","GP26",weight=1)
G1.add_edge("NGO246","GP26",weight=1)
G1.add_edge("NGO7","GP27",weight=1)
G1.add_edge("NGO10","GP27",weight=1)
G1.add_edge("NGO22","GP27",weight=1)
G1.add_edge("NGO49","GP27",weight=1)
G1.add_edge("NGO56","GP27",weight=1)
G1.add_edge("NGO132","GP27",weight=1)
G1.add_edge("NGO186","GP27",weight=1)
G1.add_edge("NGO196","GP27",weight=1)
G1.add_edge("NGO244","GP27",weight=1)
G1.add_edge("NGO266","GP27",weight=1)
G1.add_edge("NGO272","GP27",weight=1)
G1.add_edge("NGO7","GP28",weight=1)
G1.add_edge("NGO27","GP28",weight=1)
G1.add_edge("NGO225","GP28",weight=1)
G1.add_edge("NGO7","GP29",weight=1)
G1.add_edge("NGO7","GP30",weight=1)
G1.add_edge("NGO20","GP30",weight=1)
G1.add_edge("NGO7","GP31",weight=1)
G1.add_edge("NGO8","GP32",weight=1)
G1.add_edge("NGO10","GP33",weight=1)
G1.add_edge("NGO46","GP33",weight=1)
G1.add_edge("NGO50","GP33",weight=1)
G1.add_edge("NGO56","GP33",weight=1)
G1.add_edge("NGO132","GP33",weight=1)
G1.add_edge("NGO140","GP33",weight=1)
G1.add_edge("NGO10","GP34",weight=1)
G1.add_edge("NGO10","GP35",weight=1)
G1.add_edge("NGO176","GP35",weight=1)
G1.add_edge("NGO221","GP35",weight=1)
G1.add_edge("NGO10","GP36",weight=1)
G1.add_edge("NGO16","GP36",weight=1)
G1.add_edge("NGO10","GP37",weight=1)
G1.add_edge("NGO25","GP37",weight=1)
G1.add_edge("NGO11","GP38",weight=1)
G1.add_edge("NGO13","GP39",weight=1)
G1.add_edge("NGO25","GP39",weight=1)
G1.add_edge("NGO55","GP39",weight=1)
G1.add_edge("NGO94","GP39",weight=1)
G1.add_edge("NGO199","GP39",weight=1)
G1.add_edge("NGO244","GP39",weight=1)
G1.add_edge("NGO246","GP39",weight=1)
G1.add_edge("NGO274","GP39",weight=1)
G1.add_edge("NGO15","GP40",weight=1)
G1.add_edge("NGO15","GP41",weight=1)
G1.add_edge("NGO15","GP42",weight=1)
G1.add_edge("NGO15","GP43",weight=1)
G1.add_edge("NGO16","GP44",weight=1)
G1.add_edge("NGO40","GP44",weight=1)
G1.add_edge("NGO54","GP44",weight=1)
G1.add_edge("NGO176","GP44",weight=1)
G1.add_edge("NGO189","GP44",weight=1)
G1.add_edge("NGO199","GP44",weight=1)
G1.add_edge("NGO266","GP44",weight=1)
G1.add_edge("NGO17","GP45",weight=1)
G1.add_edge("NGO221","GP45",weight=1)
G1.add_edge("NGO17","GP46",weight=1)
G1.add_edge("NGO28","GP46",weight=1)
G1.add_edge("NGO18","GP47",weight=1)
G1.add_edge("NGO20","GP48",weight=1)
G1.add_edge("NGO21","GP49",weight=1)
G1.add_edge("NGO144","GP49",weight=1)
G1.add_edge("NGO176","GP49",weight=1)
G1.add_edge("NGO221","GP49",weight=1)
G1.add_edge("NGO275","GP49",weight=1)
G1.add_edge("NGO21","GP50",weight=1)
G1.add_edge("NGO275","GP50",weight=1)
G1.add_edge("NGO22","GP51",weight=1)
G1.add_edge("NGO269","GP51",weight=1)
G1.add_edge("NGO27","GP52",weight=1)
G1.add_edge("NGO27","GP53",weight=1)
G1.add_edge("NGO27","GP54",weight=1)
G1.add_edge("NGO27","GP55",weight=1)
G1.add_edge("NGO27","GP56",weight=1)
G1.add_edge("NGO27","GP57",weight=1)
G1.add_edge("NGO28","GP58",weight=1)
G1.add_edge("NGO28","GP59",weight=1)
G1.add_edge("NGO28","GP60",weight=1)
G1.add_edge("NGO40","GP61",weight=1)
G1.add_edge("NGO40","GP62",weight=1)
G1.add_edge("NGO40","GP63",weight=1)
G1.add_edge("NGO46","GP64",weight=1)
G1.add_edge("NGO46","GP65",weight=1)
G1.add_edge("NGO46","GP66",weight=1)
G1.add_edge("NGO46","GP67",weight=1)
G1.add_edge("NGO59","GP67",weight=1)
G1.add_edge("NGO98","GP67",weight=1)
G1.add_edge("NGO144","GP67",weight=1)
G1.add_edge("NGO176","GP67",weight=1)
G1.add_edge("NGO189","GP67",weight=1)
G1.add_edge("NGO194","GP67",weight=1)
G1.add_edge("NGO274","GP67",weight=1)
G1.add_edge("NGO46","GP68",weight=1)
G1.add_edge("NGO48","GP68",weight=1)
G1.add_edge("NGO46","GP69",weight=1)
G1.add_edge("NGO47","GP71",weight=1)
G1.add_edge("NGO47","GP72",weight=1)
G1.add_edge("NGO47","GP73",weight=1)
G1.add_edge("NGO58","GP73",weight=1)
G1.add_edge("NGO48","GP74",weight=1)
G1.add_edge("NGO48","GP75",weight=1)
G1.add_edge("NGO48","GP76",weight=1)
G1.add_edge("NGO48","GP77",weight=1)
G1.add_edge("NGO48","GP78",weight=1)
G1.add_edge("NGO48","GP79",weight=1)
G1.add_edge("NGO49","GP80",weight=1)
G1.add_edge("NGO50","GP81",weight=1)
G1.add_edge("NGO140","GP81",weight=1)
G1.add_edge("NGO50","GP82",weight=1)
G1.add_edge("NGO50","GP83",weight=1)
G1.add_edge("NGO50","GP84",weight=1)
G1.add_edge("NGO50","GP85",weight=1)
G1.add_edge("NGO59","GP85",weight=1)
G1.add_edge("NGO129","GP85",weight=1)
G1.add_edge("NGO50","GP86",weight=1)
G1.add_edge("NGO50","GP87",weight=1)
G1.add_edge("NGO50","GP88",weight=1)
G1.add_edge("NGO50","GP89",weight=1)
G1.add_edge("NGO50","GP90",weight=1)
G1.add_edge("NGO50","GP91",weight=1)
G1.add_edge("NGO50","GP92",weight=1)
G1.add_edge("NGO51","GP93",weight=1)
G1.add_edge("NGO51","GP94",weight=1)
G1.add_edge("NGO51","GP95",weight=1)
G1.add_edge("NGO51","GP96",weight=1)
G1.add_edge("NGO53","GP97",weight=1)
G1.add_edge("NGO54","GP98",weight=1)
G1.add_edge("NGO55","GP99",weight=1)
G1.add_edge("NGO56","GP100",weight=1)
G1.add_edge("NGO90","GP100",weight=1)
G1.add_edge("NGO176","GP100",weight=1)
G1.add_edge("NGO56","GP101",weight=1)
G1.add_edge("NGO56","GP102",weight=1)
G1.add_edge("NGO57","GP103",weight=1)
G1.add_edge("NGO130","GP103",weight=1)
G1.add_edge("NGO177","GP103",weight=1)
G1.add_edge("NGO59","GP104",weight=1)
G1.add_edge("NGO59","GP105",weight=1)
G1.add_edge("NGO59","GP106",weight=1)
G1.add_edge("NGO59","GP107",weight=1)
G1.add_edge("NGO59","GP108",weight=1)
G1.add_edge("NGO59","GP109",weight=1)
G1.add_edge("NGO59","GP110",weight=1)
G1.add_edge("NGO59","GP111",weight=1)
G1.add_edge("NGO59","GP112",weight=1)
G1.add_edge("NGO59","GP113",weight=1)
G1.add_edge("NGO79","GP114",weight=1)
G1.add_edge("NGO79","GP115",weight=1)
G1.add_edge("NGO80","GP116",weight=1)
G1.add_edge("NGO81","GP117",weight=1)
G1.add_edge("NGO271","GP117",weight=1)
G1.add_edge("NGO83","GP118",weight=1)
G1.add_edge("NGO85","GP118",weight=1)
G1.add_edge("NGO85","GP119",weight=1)
G1.add_edge("NGO85","GP120",weight=1)
G1.add_edge("NGO85","GP121",weight=1)
G1.add_edge("NGO85","GP122",weight=1)
G1.add_edge("NGO87","GP123",weight=1)
G1.add_edge("NGO87","GP124",weight=1)
G1.add_edge("NGO88","GP125",weight=1)
G1.add_edge("NGO88","GP126",weight=1)
G1.add_edge("NGO88","GP127",weight=1)
G1.add_edge("NGO88","GP128",weight=1)
G1.add_edge("NGO90","GP129",weight=1)
G1.add_edge("NGO94","GP130",weight=1)
G1.add_edge("NGO94","GP131",weight=1)
G1.add_edge("NGO95","GP132",weight=1)
G1.add_edge("NGO95","GP133",weight=1)
G1.add_edge("NGO98","GP134",weight=1)
G1.add_edge("NGO98","GP135",weight=1)
G1.add_edge("NGO100","GP136",weight=1)
G1.add_edge("NGO129","GP137",weight=1)
G1.add_edge("NGO129","GP138",weight=1)
G1.add_edge("NGO136","GP142",weight=1)
G1.add_edge("NGO129","GP143",weight=1)
G1.add_edge("NGO131","GP143",weight=1)
G1.add_edge("NGO132","GP143",weight=1)
G1.add_edge("NGO150","GP143",weight=1)
G1.add_edge("NGO176","GP143",weight=1)
G1.add_edge("NGO186","GP143",weight=1)
G1.add_edge("NGO196","GP143",weight=1)
G1.add_edge("NGO199","GP143",weight=1)
G1.add_edge("NGO132","GP144",weight=1)
G1.add_edge("NGO176","GP144",weight=1)
G1.add_edge("NGO242","GP144",weight=1)
G1.add_edge("NGO132","GP145",weight=1)
G1.add_edge("NGO134","GP146",weight=1)
G1.add_edge("NGO134","GP147",weight=1)
G1.add_edge("NGO135","GP148",weight=1)
G1.add_edge("NGO135","GP149",weight=1)
G1.add_edge("NGO144","GP149",weight=1)
G1.add_edge("NGO137","GP150",weight=1)
G1.add_edge("NGO139","GP150",weight=1)
G1.add_edge("NGO142","GP150",weight=1)
G1.add_edge("NGO248","GP150",weight=1)
G1.add_edge("NGO140","GP151",weight=1)
G1.add_edge("NGO143","GP152",weight=1)
G1.add_edge("NGO144","GP153",weight=1)
G1.add_edge("NGO144","GP154",weight=1)
G1.add_edge("NGO144","GP155",weight=1)
G1.add_edge("NGO144","GP156",weight=1)
G1.add_edge("NGO174","GP156",weight=1)
G1.add_edge("NGO151","GP157",weight=1)
G1.add_edge("NGO173","GP158",weight=1)
G1.add_edge("NGO151","GP159",weight=1)
G1.add_edge("NGO173","GP159",weight=1)
G1.add_edge("NGO173","GP160",weight=1)
G1.add_edge("NGO174","GP162",weight=1)
G1.add_edge("NGO174","GP163",weight=1)
G1.add_edge("NGO174","GP164",weight=1)
G1.add_edge("NGO174","GP165",weight=1)
G1.add_edge("NGO175","GP166",weight=1)
G1.add_edge("NGO176","GP167",weight=1)
G1.add_edge("NGO176","GP168",weight=1)
G1.add_edge("NGO176","GP169",weight=1)
G1.add_edge("NGO176","GP170",weight=1)
G1.add_edge("NGO180","GP171",weight=1)
G1.add_edge("NGO180","GP172",weight=1)
G1.add_edge("NGO180","GP173",weight=1)
G1.add_edge("NGO180","GP174",weight=1)
G1.add_edge("NGO180","GP175",weight=1)
G1.add_edge("NGO93","GP176",weight=1)
G1.add_edge("NGO182","GP176",weight=1)
G1.add_edge("NGO182","GP177",weight=1)
G1.add_edge("NGO186","GP178",weight=1)
G1.add_edge("NGO186","GP179",weight=1)
G1.add_edge("NGO186","GP180",weight=1)
G1.add_edge("NGO187","GP181",weight=1)
G1.add_edge("NGO188","GP182",weight=1)
G1.add_edge("NGO189","GP183",weight=1)
G1.add_edge("NGO192","GP184",weight=1)
G1.add_edge("NGO192","GP185",weight=1)
G1.add_edge("NGO196","GP186",weight=1)
G1.add_edge("NGO196","GP187",weight=1)
G1.add_edge("NGO196","GP188",weight=1)
G1.add_edge("NGO198","GP189",weight=1)
G1.add_edge("NGO217","GP190",weight=1)
G1.add_edge("NGO217","GP191",weight=1)
G1.add_edge("NGO246","GP191",weight=1)
G1.add_edge("NGO221","GP192",weight=1)
G1.add_edge("NGO225","GP193",weight=1)
G1.add_edge("NGO225","GP194",weight=1)
G1.add_edge("NGO225","GP195",weight=1)
G1.add_edge("NGO225","GP196",weight=1)
G1.add_edge("NGO244","GP198",weight=1)
G1.add_edge("NGO245","GP199",weight=1)
G1.add_edge("NGO246","GP200",weight=1)
G1.add_edge("NGO248","GP201",weight=1)
G1.add_edge("NGO248","GP202",weight=1)
G1.add_edge("NGO248","GP203",weight=1)
G1.add_edge("NGO248","GP204",weight=1)
G1.add_edge("NGO248","GP205",weight=1)
G1.add_edge("NGO266","GP206",weight=1)
G1.add_edge("NGO266","GP207",weight=1)
G1.add_edge("NGO269","GP208",weight=1)
G1.add_edge("NGO270","GP209",weight=1)
G1.add_edge("NGO271","GP210",weight=1)
G1.add_edge("NGO273","GP211",weight=1)
G1.add_edge("NGO273","GP212",weight=1)
G1.add_edge("NGO273","GP213",weight=1)
G1.add_edge("NGO276","GP214",weight=1)
G1.add_edge("NGO276","GP215",weight=1)
G1.add_edge("NGO276","GP216",weight=1)
G1.add_edge("NGO276","GP217",weight=1)
G1.add_edge("NGO278","GP218",weight=1)
G1.add_edge("NGO278","GP219",weight=1)
G1.add_edge("NGO279","GP220",weight=1)
G1.add_edge("NGO279","GP221",weight=1)


esmall = [(u, v) for (u, v, d) in G1.edges(data=True) if d["weight"] == 1]
pos=nx.spring_layout(G1,k=None, pos=None, fixed=None, iterations=50, threshold=0.05, weight='weight', scale=1, center=None, dim=2, seed=None)

nx.draw_networkx_edges(G1, pos, edgelist=esmall, width=0.5)
nx.draw_networkx_labels(G1, pos, font_size=8, font_family="sans-serif")

nx.draw_networkx_nodes(G1, pos, nodelist=["NGO1", "NGO2","NGO4","NGO5","NGO6","NGO7","NGO8","NGO10","NGO11","NGO13","NGO15","NGO16","NGO17","NGO18","NGO19","NGO20","NGO21","NGO22","NGO25","NGO27","NGO28","NGO40"], node_color="b",node_size=200) 
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO46","NGO47","NGO48","NGO49","NGO50","NGO51","NGO52","NGO53","NGO54","NGO55","NGO56","NGO57","NGO58","NGO59"], node_color="y",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO79","NGO80","NGO81","NGO82","NGO83","NGO85","NGO87","NGO88","NGO90","NGO92","NGO93","NGO94","NGO95","NGO98","NGO99","NGO100"], node_color="r",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO129","NGO130","NGO131","NGO132","NGO134","NGO135","NGO136","NGO137","NGO139","NGO140","NGO142","NGO143","NGO144","NGO150","NGO151"], node_color="g",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO173","NGO173","NGO174","NGO175","NGO176","NGO177","NGO179", "NGO180","NGO182"], node_color="orange",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO186","NGO187","NGO88","NGO189"], node_color="purple",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO192","NGO193","NGO194"], node_color="darkgrey",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO195","NGO196","NGO197","NGO198","NGO199"], node_color="aqua",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO216","NGO217","NGO220","NGO221","NGO222","NGO225","NGO242","NGO244","NGO245","NGO246","NGO248"], node_color="fuchsia",node_size=200)
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO266","NGO268","NGO269","NGO270","NGO271","NGO272","NGO273","NGO274","NGO275","NGO276","NGO278","NGO279"],node_color="crimson",node_size=200)

nx.draw_networkx_nodes(G1, pos, nodelist=["GP1","GP10","GP100","GP101","GP102","GP103","GP104","GP105","GP106","GP107","GP108","GP109","GP11","GP110","GP111","GP112","GP113","GP114","GP115","GP116","GP117","GP118","GP119","GP12","GP120","GP121","GP122","GP123","GP124","GP125","GP126","GP127","GP128","GP129","GP13","GP130","GP131","GP132","GP133",
                                         "GP134","GP135","GP136","GP137","GP138","GP14","GP142","GP143","GP144","GP145","GP146","GP147","GP148","GP149","GP15","GP150","GP151","GP152","GP153","GP154","GP155","GP156","GP157","GP158","GP159","GP16","GP160","GP162","GP163","GP164","GP165","GP166","GP167","GP168","GP169","GP17","GP170","GP171","GP172",
                                         "GP173","GP174","GP175","GP176","GP177","GP178","GP179","GP18","GP180","GP181","GP182","GP183","GP184","GP185","GP186","GP187","GP188","GP189","GP19","GP190","GP191","GP192","GP193","GP194","GP195","GP196","GP198","GP199","GP2","GP20","GP200","GP201","GP202","GP203","GP204","GP205","GP206","GP207","GP208",
                                         "GP209","GP21","GP210","GP211","GP212","GP213","GP214","GP215","GP216","GP217","GP218","GP219","GP22","GP220","GP221","GP23","GP24","GP25","GP26","GP27","GP28","GP29","GP3","GP30","GP31","GP32","GP33","GP34","GP35","GP36","GP37","GP38","GP39","GP4","GP40","GP41","GP42","GP43","GP44","GP45","GP46","GP47","GP48"
                                         ,"GP49","GP5","GP50","GP51","GP52","GP53","GP54","GP55","GP56","GP57","GP58","GP59","GP6","GP60","GP61","GP62","GP63","GP64","GP65","GP66","GP67","GP68","GP69","GP7","GP71","GP72","GP73","GP74","GP75","GP76","GP77","GP78","GP79","GP8","GP80","GP81","GP82","GP83","GP84","GP85","GP86","GP87","GP88","GP89","GP9",
                                         "GP90","GP91","GP92","GP93","GP94","GP95","GP96","GP97","GP98","GP99"], node_color="lightpink",node_size=200)
fig = plt.gcf()
fig.set_size_inches(20,10)
plt.axis("on")
plt.tight_layout(pad=2, h_pad=None, w_pad=None, rect=None)
plt.title("The Graph analysis of partnership relations between Global and West/ East African Countries")
plt.show()

# %%
cen1=nx.degree_centrality(G1)

# %%
k = Counter(cen1)
h = k.most_common(10)
h
# Out:
# [('GP15', 0.1111111111111111),
#  ('GP11', 0.08950617283950617),
#  ('GP21', 0.05555555555555555),
#  ('NGO50', 0.05246913580246913),
#  ('GP6', 0.04938271604938271),
#  ('NGO2', 0.040123456790123455),
#  ('NGO10', 0.040123456790123455),
#  ('NGO176', 0.040123456790123455),
#  ('GP19', 0.040123456790123455),
#  ('NGO59', 0.037037037037037035)]

# %%
cen2 = nx.eigenvector_centrality(G1)

# %%
k = Counter(cen2)
h1 = k.most_common(10)
h1
# Out:
# [('GP15', 0.36363924581493784),
#  ('GP11', 0.3446787091133487),
#  ('GP21', 0.2433673116548342),
#  ('NGO10', 0.22242645857714025),
#  ('GP6', 0.21571186537337733),
#  ('GP19', 0.18128259474917546),
#  ('NGO7', 0.1743911185212908),
#  ('NGO266', 0.1621923379817429),
#  ('NGO50', 0.15474930813770893),
#  ('NGO2', 0.15276647369193136)]

# %%
cen3 = nx.betweenness_centrality(G1)

# %%
k = Counter(cen3)
h1 = k.most_common(10)
h1
# Out:
# [('GP15', 0.2969602736136466),
#  ('GP11', 0.1384702955007414),
#  ('GP21', 0.09263919266309634),
#  ('NGO7', 0.07900424281533154),
#  ('NGO50', 0.07082161125961631),
#  ('NGO144', 0.06413965770655357),
#  ('NGO2', 0.05310871537503566),
#  ('GP19', 0.05192013698986445),
#  ('NGO59', 0.05089302286652339),
#  ('GP67', 0.04985930016137194)]

# %%
cen4 = nx.closeness_centrality(G1)

# %%
k = Counter(cen4)
h = k.most_common(10)
h
# Out:
# [('GP15', 0.3034865900383142),
#  ('NGO7', 0.2795778624876465),
#  ('NGO10', 0.2733264320220842),
#  ('GP11', 0.2733264320220842),
#  ('NGO266', 0.268654185320852),
#  ('NGO244', 0.2673484541649791),
#  ('GP21', 0.2647747025003343),
#  ('NGO2', 0.25794581216621076),
#  ('NGO273', 0.25794581216621076),
#  ('NGO4', 0.2567418643848049)]

# %%
import networkx.algorithms.community as nx_comm
nx_comm.modularity(G1, nx_comm.label_propagation_communities(G1))
# Out:
# 0.561355889407903

# %%
nx.density(G1)
# Out:
# 0.00845204178537512

# %%
nx.degree_assortativity_coefficient(G1)
# Out:
# -0.06933206222455046

# %%
nx.average_clustering(G1)
# Out:
# 0.0

# %%
nx.transitivity(G1)
# Out:
# 0
