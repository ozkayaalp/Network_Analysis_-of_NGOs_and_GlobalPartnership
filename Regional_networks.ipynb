# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# #### Building Regional Level Network

# %%
G1=nx.Graph()

G1.add_edge("NGO2","RI5")
G1.add_edge("NGO2","RI6")
G1.add_edge("NGO3","RI8")
G1.add_edge("NGO3","NGO30")
G1.add_edge("NGO4","NGO31")
G1.add_edge("NGO216","NGO33")
G1.add_edge("NGO249","NGO33")
G1.add_edge("NGO255","NGO33")
G1.add_edge("NGO256","NGO33")
G1.add_edge("NGO257","NGO33")
G1.add_edge("NGO258","NGO33")
G1.add_edge("NGO259","NGO33")
G1.add_edge("NGO260","NGO33")
G1.add_edge("NGO261","NGO33")
G1.add_edge("NGO262","NGO33")
G1.add_edge("NGO263","NGO33")
G1.add_edge("NGO264","NGO33")
G1.add_edge("NGO265","NGO33")
G1.add_edge("NGO266","NGO33")
G1.add_edge("NGO267","NGO33")
G1.add_edge("NGO268","NGO33")
G1.add_edge("NGO269","NGO33")
G1.add_edge("NGO270","NGO33")
G1.add_edge("NGO271","NGO33")
G1.add_edge("NGO272","NGO33")
G1.add_edge("NGO273","NGO33")
G1.add_edge("NGO274","NGO33")
G1.add_edge("NGO275","NGO33")
G1.add_edge("NGO276","NGO33")
G1.add_edge("NGO277","NGO33")
G1.add_edge("NGO278","NGO33")
G1.add_edge("NGO279","NGO33")
G1.add_edge("NGO47","NGO60")
G1.add_edge("NGO54","NGO65")
G1.add_edge("NGO55","NGO66")
G1.add_edge("NGO91","NGO105")
G1.add_edge("NGO96","NGO108")
G1.add_edge("NGO134","NGO96")
G1.add_edge("NGO136","RI17")
G1.add_edge("NGO136","RI18")
G1.add_edge("NGO197","NGO200")
G1.add_edge("NGO199","NGO212")
G1.add_edge("NGO255","NGO212")
G1.add_edge("NGO256","NGO212")
G1.add_edge("NGO257","NGO212")
G1.add_edge("NGO258","NGO212")
G1.add_edge("NGO259","NGO212")
G1.add_edge("NGO260","NGO212")
G1.add_edge("NGO261","NGO212")
G1.add_edge("NGO262","NGO212")
G1.add_edge("NGO263","NGO212")
G1.add_edge("NGO264","NGO212")
G1.add_edge("NGO265","NGO212")
G1.add_edge("NGO266","NGO212")
G1.add_edge("NGO267","NGO212")
G1.add_edge("NGO268","NGO212")
G1.add_edge("NGO269","NGO212")
G1.add_edge("NGO270","NGO212")
G1.add_edge("NGO271","NGO212")
G1.add_edge("NGO272","NGO212")
G1.add_edge("NGO273","NGO212")
G1.add_edge("NGO274","NGO212")
G1.add_edge("NGO275","NGO212")
G1.add_edge("NGO276","NGO212")
G1.add_edge("NGO277","NGO212")
G1.add_edge("NGO278","NGO212")
G1.add_edge("NGO279","NGO212")
G1.add_edge("NGO216","NGO197")
G1.add_edge("NGO217","NGO197")
G1.add_edge("NGO218","NGO197")
G1.add_edge("NGO219","NGO197")
G1.add_edge("NGO220","NGO197")
G1.add_edge("NGO221","NGO197")
G1.add_edge("NGO222","NGO197")
G1.add_edge("NGO223","NGO197")
G1.add_edge("NGO224","NGO197")
G1.add_edge("NGO225","NGO197")
G1.add_edge("NGO226","NGO197")
G1.add_edge("NGO227","NGO197")
G1.add_edge("NGO228","NGO197")
G1.add_edge("NGO229","NGO197")
G1.add_edge("NGO230","NGO197")
G1.add_edge("NGO231","NGO197")
G1.add_edge("NGO232","NGO197")
G1.add_edge("NGO233","NGO197")
G1.add_edge("NGO234","NGO197")
G1.add_edge("NGO235","NGO197")
G1.add_edge("NGO236","NGO197")
G1.add_edge("NGO237","NGO197")
G1.add_edge("NGO239","NGO197")
G1.add_edge("NGO240","NGO197")
G1.add_edge("NGO241","NGO197")
G1.add_edge("NGO242","NGO197")
G1.add_edge("NGO243","NGO197")
G1.add_edge("NGO244","NGO197")
G1.add_edge("NGO245","NGO197")
G1.add_edge("NGO246","NGO197")
G1.add_edge("NGO247","NGO197")
G1.add_edge("NGO248","NGO197")
G1.add_edge("NGO249","NGO197")
G1.add_edge("NGO216","NGO56")
G1.add_edge("NGO249","NGO56")
G1.add_edge("NGO246","NGO250")
G1.add_edge("NGO246","NGO251")
G1.add_edge("NGO255","NGO246")
G1.add_edge("NGO256","NGO246")
G1.add_edge("NGO257","NGO246")
G1.add_edge("NGO258","NGO246")
G1.add_edge("NGO259","NGO246")
G1.add_edge("NGO260","NGO246")
G1.add_edge("NGO261","NGO246")
G1.add_edge("NGO262","NGO246")
G1.add_edge("NGO263","NGO246")
G1.add_edge("NGO264","NGO246")
G1.add_edge("NGO265","NGO246")
G1.add_edge("NGO266","NGO246")
G1.add_edge("NGO267","NGO246")
G1.add_edge("NGO268","NGO246")
G1.add_edge("NGO269","NGO246")
G1.add_edge("NGO270","NGO246")
G1.add_edge("NGO271","NGO246")
G1.add_edge("NGO272","NGO246")
G1.add_edge("NGO273","NGO246")
G1.add_edge("NGO274","NGO246")
G1.add_edge("NGO275","NGO246")
G1.add_edge("NGO276","NGO246")
G1.add_edge("NGO277","NGO246")
G1.add_edge("NGO278","NGO246")
G1.add_edge("NGO279","NGO246")
G1.add_edge("NGO255","NGO197")
G1.add_edge("NGO256","NGO197")
G1.add_edge("NGO257","NGO197")
G1.add_edge("NGO258","NGO197")
G1.add_edge("NGO259","NGO197")
G1.add_edge("NGO260","NGO197")
G1.add_edge("NGO261","NGO197")
G1.add_edge("NGO262","NGO197")
G1.add_edge("NGO263","NGO197")
G1.add_edge("NGO264","NGO197")
G1.add_edge("NGO265","NGO197")
G1.add_edge("NGO266","NGO197")
G1.add_edge("NGO267","NGO197")
G1.add_edge("NGO268","NGO197")
G1.add_edge("NGO269","NGO197")
G1.add_edge("NGO270","NGO197")
G1.add_edge("NGO271","NGO197")
G1.add_edge("NGO272","NGO197")
G1.add_edge("NGO273","NGO197")
G1.add_edge("NGO274","NGO197")
G1.add_edge("NGO275","NGO197")
G1.add_edge("NGO276","NGO197")
G1.add_edge("NGO277","NGO197")
G1.add_edge("NGO278","NGO197")
G1.add_edge("NGO279","NGO197")
G1.add_edge("NGO229","NGO60")
G1.add_edge("NGO236","NGO65")
G1.add_edge("NGO237","NGO66")
G1.add_edge("NGO260","NGO105")
G1.add_edge("NGO265","NGO108")
G1.add_edge("NGO275","NGO96")
G1.add_edge("NGO277","RI17")
G1.add_edge("NGO277","RI18")
G1.add_edge("NGO197","NGO200")
G1.add_edge("NGO199","NGO212")
G1.add_edge("NGO216","NGO197")
G1.add_edge("NGO217","NGO197")
G1.add_edge("NGO218","NGO197")
G1.add_edge("NGO219","NGO197")
G1.add_edge("NGO220","NGO197")
G1.add_edge("NGO221","NGO197")
G1.add_edge("NGO222","NGO197")
G1.add_edge("NGO223","NGO197")
G1.add_edge("NGO224","NGO197")
G1.add_edge("NGO225","NGO197")
G1.add_edge("NGO226","NGO197")
G1.add_edge("NGO227","NGO197")
G1.add_edge("NGO228","NGO197")
G1.add_edge("NGO229","NGO197")
G1.add_edge("NGO230","NGO197")
G1.add_edge("NGO231","NGO197")
G1.add_edge("NGO232","NGO197")
G1.add_edge("NGO233","NGO197")
G1.add_edge("NGO234","NGO197")
G1.add_edge("NGO235","NGO197")
G1.add_edge("NGO236","NGO197")
G1.add_edge("NGO237","NGO197")
G1.add_edge("NGO239","NGO197")
G1.add_edge("NGO240","NGO197")
G1.add_edge("NGO241","NGO197")
G1.add_edge("NGO242","NGO197")
G1.add_edge("NGO243","NGO197")
G1.add_edge("NGO244","NGO197")
G1.add_edge("NGO245","NGO197")
G1.add_edge("NGO246","NGO197")
G1.add_edge("NGO247","NGO197")
G1.add_edge("NGO248","NGO197")
G1.add_edge("NGO249","NGO197")
G1.add_edge("NGO216","NGO56")
G1.add_edge("NGO249","NGO56")
G1.add_edge("NGO246","NGO250")
G1.add_edge("NGO246","NGO251")
G1.add_edge("NGO249","NGO246")
G1.add_edge("NGO255","NGO246")
G1.add_edge("NGO256","NGO246")
G1.add_edge("NGO257","NGO246")
G1.add_edge("NGO258","NGO246")
G1.add_edge("NGO259","NGO246")
G1.add_edge("NGO260","NGO246")
G1.add_edge("NGO261","NGO246")
G1.add_edge("NGO262","NGO246")
G1.add_edge("NGO263","NGO246")
G1.add_edge("NGO264","NGO246")
G1.add_edge("NGO265","NGO246")
G1.add_edge("NGO266","NGO246")
G1.add_edge("NGO267","NGO246")
G1.add_edge("NGO268","NGO246")
G1.add_edge("NGO269","NGO246")
G1.add_edge("NGO270","NGO246")
G1.add_edge("NGO271","NGO246")
G1.add_edge("NGO272","NGO246")
G1.add_edge("NGO273","NGO246")
G1.add_edge("NGO274","NGO246")
G1.add_edge("NGO275","NGO246")
G1.add_edge("NGO276","NGO246")
G1.add_edge("NGO277","NGO246")
G1.add_edge("NGO278","NGO246")
G1.add_edge("NGO279","NGO246")
G1.add_edge("NGO255","NGO197")
G1.add_edge("NGO256","NGO197")
G1.add_edge("NGO257","NGO197")
G1.add_edge("NGO258","NGO197")
G1.add_edge("NGO259","NGO197")
G1.add_edge("NGO260","NGO197")
G1.add_edge("NGO261","NGO197")
G1.add_edge("NGO262","NGO197")
G1.add_edge("NGO263","NGO197")
G1.add_edge("NGO264","NGO197")
G1.add_edge("NGO265","NGO197")
G1.add_edge("NGO266","NGO197")
G1.add_edge("NGO267","NGO197")
G1.add_edge("NGO268","NGO197")
G1.add_edge("NGO269","NGO197")
G1.add_edge("NGO270","NGO197")
G1.add_edge("NGO271","NGO197")
G1.add_edge("NGO272","NGO197")
G1.add_edge("NGO273","NGO197")
G1.add_edge("NGO274","NGO197")
G1.add_edge("NGO275","NGO197")
G1.add_edge("NGO276","NGO197")
G1.add_edge("NGO277","NGO197")
G1.add_edge("NGO278","NGO197")
G1.add_edge("NGO279","NGO197")



pos=nx.spring_layout(G1,k=None, pos=None, fixed=None, iterations=50, threshold=0.05, weight='weight', scale=1, center=None, dim=2, seed=None)


nx.draw_networkx_nodes(G1, pos, nodelist=["NGO2","NGO3","NGO4","RI5","RI6","RI8","NGO30","NGO31","NGO33"], node_color="b",node_size=200,label='Kenya')
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO47","NGO54","NGO55","NGO56","NGO47","NGO60","NGO65","NGO66"], node_color="y",node_size=200, label='Malawi')
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO91","NGO96","NGO105","NGO108","NGO91"], node_color="r",node_size=200,label='Tanzania')
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO134","NGO136","NGO96","RI17","RI18"], node_color="g",node_size=200,label='Uganda')
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO197","NGO199","NGO200","NGO212"], node_color="aqua",node_size=200, label= 'Cote D’Ivoire')
nx.draw_networkx_nodes(G1, pos, noBdelist=["NGO216","NGO217","NGO220","NGO221","NGO222","NGO225","NGO242","NGO244","NGO245","NGO246","NGO247","NGO248", 'NGO249',"NGO226","NGO244","NGO243"], node_color="fuchsia",node_size=200,label='Ghana')
nx.draw_networkx_nodes(G1, pos, nodelist=["NGO255","NGO256","NGO257","NGO258","NGO259","NGO260","NGO261","NGO262","NGO263","NGO264","NGO265","NGO266","NGO267","NGO268","NGO269","NGO270","NGO271","NGO272","NGO273","NGO274","NGO275","NGO276","NGO277","NGO278","NGO279","NGO273"
                                         ,'NGO251'],node_color="crimson",node_size=200, label= 'Senegal')
                                         

nx.draw_networkx_edges(G1, pos, width=0.3)
nx.draw_networkx_labels(G1, pos, font_size=8, font_family="sans-serif")

fig = plt.gcf()
fig.set_size_inches(20,10)
plt.axis("on")
plt.title("Regional level NGOs network")
plt.plot(label='Kenya')
plt.legend()
plt.savefig('regionalnetwork.png')

# %% [markdown]
# #### Regional Level Network Centrality Metrics

# %%
cen1=nx.degree_centrality(G1)

# %%
k = Counter(cen1)
h = k.most_common(10)
h
# Out:
# [('NGO197', 0.6781609195402298),
#  ('NGO246', 0.3333333333333333),
#  ('NGO33', 0.3103448275862069),
#  ('NGO212', 0.29885057471264365),
#  ('NGO277', 0.06896551724137931),
#  ('NGO260', 0.05747126436781609),
#  ('NGO265', 0.05747126436781609),
#  ('NGO275', 0.05747126436781609),
#  ('NGO249', 0.04597701149425287),
#  ('NGO255', 0.04597701149425287)]

# %%
cen2 = nx.eigenvector_centrality(G1)

# %%
k = Counter(cen2)
h1 = k.most_common(10)
h1
# Out:
# [('NGO197', 0.45768583254379164),
#  ('NGO246', 0.34926890547241607),
#  ('NGO33', 0.30830807052643694),
#  ('NGO212', 0.29490862284682645),
#  ('NGO277', 0.13052776864085977),
#  ('NGO275', 0.12951937159012325),
#  ('NGO265', 0.12951027045622115),
#  ('NGO260', 0.12941010797991181),
#  ('NGO255', 0.12832947021716673),
#  ('NGO256', 0.12832947021716673)]

# %%
cen3 = nx.betweenness_centrality(G1)

# %%
k = Counter(cen3)
h1 = k.most_common(10)
h1
# Out:
# [('NGO197', 0.6375300721732157),
#  ('NGO246', 0.08050432148266956),
#  ('NGO277', 0.06244928950088004),
#  ('NGO212', 0.0549318364073777),
#  ('NGO33', 0.04570970328789093),
#  ('NGO260', 0.042534828126915857),
#  ('NGO275', 0.041465595301468115),
#  ('NGO229', 0.04116546377973804),
#  ('NGO236', 0.04116546377973804),
#  ('NGO237', 0.04116546377973804)]

# %%
cen4 = nx.closeness_centrality(G1)

# %%
k = Counter(cen4)
h = k.most_common(10)
h
# Out:
# [('NGO197', 0.6767512470180004),
#  ('NGO246', 0.5051805083373806),
#  ('NGO277', 0.4244711963544855),
#  ('NGO275', 0.421974306964165),
#  ('NGO260', 0.4195066209585266),
#  ('NGO265', 0.4195066209585266),
#  ('NGO255', 0.40991789819376023),
#  ('NGO256', 0.40991789819376023),
#  ('NGO257', 0.40991789819376023),
#  ('NGO258', 0.40991789819376023)]

# %%
import networkx.algorithms.community as nx_comm
nx_comm.modularity(G1, nx_comm.label_propagation_communities(G1))
# Out:
# 0.1794572622228914

# %%
nx.density(G1)
# Out:
# 0.04258098223615465

# %%
nx.degree_assortativity_coefficient(G1)
# Out:
# -0.5642953573995584

# %%
nx.average_clustering(G1)
# Out:
# 0.046733733342441686

# %%
nx.transitivity(G1)
# Out:
# 0.02608695652173913
